# %%
import csv
import pandas as pd

# %%
sent_df = pd.read_csv('data/opafy23nid.csv')

# %%
sent_df
# Out:
#      DISGORGE  CPIDN  AMENDYR BUSTEXT  OWNSTEXT FINSTXT  FINDOTXT OFENTXT1  \
# 0         NaN   1846      NaN     NaN       NaN     NaN       NaN      NaN
# 1         NaN   1847      NaN     NaN       NaN     NaN       NaN      NaN
# 2         0.0   1848      NaN     NaN       NaN     NaN       NaN      NaN
# 3         NaN   1849   2000.0     NaN       NaN     NaN       NaN      NaN
# 4         NaN   1850      NaN     NaN       NaN     NaN       NaN      NaN
# ..        ...    ...      ...     ...       ...     ...       ...      ...
# 247       0.0   2101      NaN     NaN       NaN     NaN       NaN      NaN
# 248       0.0   2102   2001.0     NaN       NaN     NaN       NaN      NaN
# 249       0.0   2103   2001.0     NaN       NaN     NaN       NaN      NaN
# 250       0.0   2131   2000.0     NaN       NaN     NaN       NaN      NaN
# 251       0.0   2132   2001.0     NaN       NaN     NaN       NaN      NaN
#
# ...
